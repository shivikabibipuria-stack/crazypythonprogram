# %% [markdown]
# <a href="https://colab.research.google.com/github/shivikabibipuria-stack/crazypythonprogram/blob/main/pythonbasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
name = "Alice"
age = 18
height = 5.4

print(name, age, height)
# Out:
# Alice 18 5.4

# %%
name = input("Enter your name: ")
print("Welcome,", name)
# Out:
# Enter your name: shivika
# Welcome, shivika

# %%
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335

# %%
num = "25"
num = int(num)
print(num + 5)
# Out:
# 30
